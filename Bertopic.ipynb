# %%
pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 61.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.3.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039282 sha256=9fed597d7f0a4db00399116203a6cc75289cfe571365d7451dd2ccd1243d13ce
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=4cfaefe782569519dc81a3b0d4f570be3cfbda30ae71c3b3318442a9f5abd144
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: sentencepiece, cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.3.0 sentencepiece-0.1.99 umap-learn-0.5.5

# %%
# Choose an embedding backend
# !pip install bertopic[flair, gensim, spacy, use]

# Topic modeling with images
# !pip install bertopic[vision]
# Out:
# ERROR: Invalid requirement: 'bertopic[flair,'
# Requirement already satisfied: bertopic[vision] in /usr/local/lib/python3.10/dist-packages (0.16.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (2.3.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (5.15.0)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[vision]) (9.4.0)
# Collecting accelerate>=0.19.0 (from bertopic[vision])
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->bertopic[vision]) (0.4.1)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[vision]) (0.29.37)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[vision]) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[vision]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[vision]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[vision]) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[vision]) (8.2.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[vision]) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[vision]) (4.35.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[vision]) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[vision]) (0.1.99)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[vision]) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[vision]) (0.5.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic[vision]) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[vision]) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic[vision]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic[vision]) (0.15.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[vision]) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate>=0.19.0->bertopic[vision]) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate>=0.19.0->bertopic[vision]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.26.1

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                              Name  \
# 0       -1   6586                  -1_to_of_the_and
# 1        0   1828              0_game_team_games_he
# 2        1    607     1_key_clipper_chip_encryption
# 3        2    525              2_ites_cheek_yep_huh
# 4        3    453        3_israel_israeli_jews_arab
# ..     ...    ...                               ...
# 223    222     10             222_vv_mac_eeee_eeeee
# 224    223     10    223_melbourne_sgi_format_2476v
# 225    224     10          224_ear_hearing_wax_ears
# 226    225     10  225_contains_tune_dykstra_chorus
# 227    226     10     226_alarm_sensor_alarms_shock
#
#                                         Representation  \
# 0       [to, of, the, and, is, you, for, in, it, that]
# 1    [game, team, games, he, players, season, hocke...
# 2    [key, clipper, chip, encryption, keys, escrow,...
# 3    [ites, cheek, yep, huh, ken, ignore, why, each...
# 4    [israel, israeli, jews, arab, jewish, arabs, p...
# ..                                                 ...
# 223  [vv, mac, eeee, eeeee, iigs, disks, disk, 35, ...
# 224  [melbourne, sgi, format, 2476v, 3001, mgregory...
# 225  [ear, hearing, wax, ears, syringe, widex, vida...
# 226  [contains, tune, dykstra, chorus, chrysler, ne...
# 227  [alarm, sensor, alarms, shock, car, viper, alp...
#
#                                    Representative_Docs
# 0    [Golgotha the whole process of the fall of man...
# 1    [1992-93 Los Angeles Kings notes and game repo...
# 2    [Here is a revised version of my summary which...
# 3    [\nYep.\n, ites:, \n \n                       ...
# 4    [\nThis a "tried and true" method utilized by ...
# ..                                                 ...
# 223  [\nI don't know the answer to your direct ques...
# 224  [Charles Boesel writes\n(sci.image.processing,...
# 225  [\nVida> Can one develop inner-ear problems fr...
# 226  [Just a little something I found while reading...
# 227  [Just found a great deal on a Clifford Delta c...
#
# [228 rows x 5 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('game', 0.010235858502422356),
#  ('team', 0.00893544951672369),
#  ('games', 0.007123536352839394),
#  ('he', 0.006887812072795355),
#  ('players', 0.006282197047462496),
#  ('season', 0.006177285737100019),
#  ('hockey', 0.006080060891283855),
#  ('play', 0.005731631177980552),
#  ('25', 0.0055868159206700985),
#  ('year', 0.0055331633417785905)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      0
# 1      My brother is in the market for a high-perform...      8
# 2      \n\n\n\n\tFinally you said what you dream abou...     -1
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...     31
# 4      1)    I have an old Jasmine drive which I cann...     82
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...     37
# 18842  \nNot in isolated ground recepticles (usually ...    182
# 18843  I just installed a DX2-66 CPU in a clone mothe...     88
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...    149
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      4
#
#                                          Name  \
# 0                        0_game_team_games_he
# 1               8_card_drivers_diamond_driver
# 2                            -1_to_of_the_and
# 3                     31_scsi_scsi2_scsi1_ide
# 4                  82_tape_backup_tapes_drive
# ...                                       ...
# 18841      37_doctor_patients_medical_candida
# 18842  182_ground_grounding_conductor_neutral
# 18843                    88_fan_cpu_heat_sink
# 18844            149_den_sphere_radius_points
# 18845                  4_car_cars_engine_ford
#
#                                           Representation  \
# 0      [game, team, games, he, players, season, hocke...
# 1      [card, drivers, diamond, driver, ati, video, c...
# 2         [to, of, the, and, is, you, for, in, it, that]
# 3      [scsi, scsi2, scsi1, ide, drive, controller, a...
# 4      [tape, backup, tapes, drive, munroe, wangdat, ...
# ...                                                  ...
# 18841  [doctor, patients, medical, candida, medicine,...
# 18842  [ground, grounding, conductor, neutral, wire, ...
# 18843  [fan, cpu, heat, sink, fans, cooling, chip, co...
# 18844  [den, sphere, radius, points, plane, ellipse, ...
# 18845  [car, cars, engine, ford, mustang, toyota, v8,...
#
#                                      Representative_Docs  \
# 0      [1992-93 Los Angeles Kings notes and game repo...
# 1      [I have uploaded the most recent Windows drive...
# 2      [Golgotha the whole process of the fall of man...
# 3      [The above does not tell the proper story of S...
# 4      [hello all- i have a problem with my micro sol...
# ...                                                  ...
# 18841  [The biggest reason why the cost of medical ca...
# 18842  [\nNot according to the NEC nor the CEC, as ex...
# 18843  [N(P>Just got a 66MHz 486DX2 system, and am co...
# 18844  [\nHere is one by Andrew "Graphics Gems" Glass...
# 18845  [\nWhile I don't read normally read this group...
#
#                                              Top_n_words  Probability  \
# 0      game - team - games - he - players - season - ...     1.000000
# 1      card - drivers - diamond - driver - ati - vide...     0.689812
# 2      to - of - the - and - is - you - for - in - it...     0.000000
# 3      scsi - scsi2 - scsi1 - ide - drive - controlle...     0.492934
# 4      tape - backup - tapes - drive - munroe - wangd...     0.551420
# ...                                                  ...          ...
# 18841  doctor - patients - medical - candida - medici...     1.000000
# 18842  ground - grounding - conductor - neutral - wir...     0.609899
# 18843  fan - cpu - heat - sink - fans - cooling - chi...     0.302402
# 18844  den - sphere - radius - points - plane - ellip...     1.000000
# 18845  car - cars - engine - ford - mustang - toyota ...     1.000000
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18841                    False
# 18842                    False
# 18843                    False
# 18844                    False
# 18845                    False
#
# [18846 rows x 8 columns]
